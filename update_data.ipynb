# %%
import numpy as np
import pandas as pd
from WindPy import *  
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2020 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
month_dict = pd.read_excel('data_month.xlsx', sheet_name=1)
month_data = pd.read_excel('data_month.xlsx', sheet_name=0, index_col= 0 )
month_data
# Out:
#             SIP   IVA    IEP       IEE        IEO      IET       NSI      NSP  \
# Date
# 1992-01-31  NaN  10.9    NaN       NaN        NaN      NaN       NaN      NaN
# 1992-02-29  NaN  18.5    NaN       NaN        NaN      NaN       NaN      NaN
# 1992-03-31  NaN  16.8    NaN       NaN        NaN      NaN       NaN      NaN
# 1992-04-30  NaN  15.1    NaN       NaN        NaN      NaN       NaN      NaN
# 1992-05-31  NaN  14.3    NaN       NaN        NaN      NaN       NaN      NaN
# ...         ...   ...    ...       ...        ...      ...       ...      ...
# 2022-09-30  1.3   6.3   96.6  114362.0  1001708.2  62441.8  596682.4  34021.8
# 2022-10-31  0.1   5.0  100.2  127458.0  1117838.7  69768.2  664199.6  36196.9
# 2022-11-30 -1.9   2.2   96.6  140467.0  1239568.9  77179.6  730010.5  38595.9
# 2022-12-31 -0.8   1.3   96.7  153427.0  1379098.4  84038.5  825967.4  43148.2
# 2023-01-31  NaN   NaN    NaN       NaN        NaN      NaN       NaN      NaN
#
# ...

# %%
month_dict['']
# Out:
#    Code                                             Factor  \
# 0   SIP    Service industry production index: year-on-year
# 1   IVA               Industrial value added: year-on-year
# 2   IEP  Industrial enterprises: Production and sales r...
# 3   IEE  Industrial Enterprises: Export Delivery Value:...
# 4   IEO  Industrial enterprises: Operating income: Cumu...
# ..  ...                                                ...
# 76  UOS  Unofficial China Services PMI: Business Activi...
# 77  UOO        Unofficial China Composite PMI:Output Index
# 78  CCI                          Consumer Confidence Index
# 79  CSI                        Consumer Satisfaction Index
# 80  CEI                         Consumer Expectation Index
#
#              Factor_CN       Unit        ID begin_time  \
# 0         服务业生产指数:当月同比          %  M5767203    2016-12
# 1           工业增加值:当月同比          %  M0000545    1990-01
# 2         工业企业:产销率:累计值          %  M0041768    2001-01
# ...

# %%
pd.read_excel('all_data_month.xlsx', sheet_name=1)['ID']
# Out:
#    Code                                             Factor  \
# 0   SIP    Service industry production index: year-on-year
# 1   IVA               Industrial value added: year-on-year
# 2   IEP  Industrial enterprises: Production and sales r...
# 3   IEE  Industrial Enterprises: Export Delivery Value:...
# 4   IEO  Industrial enterprises: Operating income: Cumu...
# ..  ...                                                ...
# 77  UOS  Unofficial China Services PMI: Business Activi...
# 78  UOO        Unofficial China Composite PMI:Output Index
# 79  CCI                          Consumer Confidence Index
# 80  CSI                        Consumer Satisfaction Index
# 81  CEI                         Consumer Expectation Index
#
#              Factor_CN Unit        ID begin_time      来源         更新时间
# 0         服务业生产指数:当月同比    %  M5767203    2016-12   国家统计局  '2023-01-17
# 1           工业增加值:当月同比    %  M0000545    1990-01   国家统计局  '2023-01-17
# ...

# %%
w.edb(','.join(month_dict['ID']), month_data.index[-3],datetime.date(datetime.now()), 'Fill=Previous',   usedf=True )[1]
# Out:
#             M5767203  M0000545  M0041768  M0041769   M5767811  M0000556  \
# 2022-11-30      -1.9       2.2      96.6  140467.0  1239568.9   77179.6
# 2022-12-31      -0.8       1.3      96.7  153427.0  1379098.4   84038.5
# 2023-01-31      -0.8       1.3      96.7  153427.0  1379098.4   84038.5
# 2023-02-28      -0.8       1.3      96.7  153427.0  1379098.4   84038.5
#
#             M0049801  M0049802  S0026991  S0027014  ...  M5207830  M0088875  \
# 2022-11-30  730010.5   38595.9  409407.9   76285.8  ...      45.5      43.2
# 2022-12-31  825967.4   43148.2  449583.9   83886.3  ...      42.9      43.0
# 2023-01-31  825967.4   43148.2  449583.9   83886.3  ...      46.7      43.3
# 2023-02-28  825967.4   43148.2  449583.9   83886.3  ...      50.2      50.3
#
#             M0088876  M0088877  M0000138  M0061603  M0290204  M0012303  \
# 2022-11-30      45.6      45.0      49.4      46.7      47.0      85.5
# 2022-12-31      45.4      40.4      49.0      48.0      48.3      88.3
# ...

# %%
','.join(month_dict['ID'])
# Out:
# 'M5767203,M0000545,M0041768,M0041769,M5767811,M0000556,M0049801,M0049802,S0026991,S0027014,M0000612,M0085932,M0001227,M0000604,M0000606,M0000608,C5756400,V0989584,M0009870,M0000272,S0029656,M0001439,M0001483,M0001385,M0009970,M0009941,M5542229,M0010049,M5207845,M5207847,M5405536,M5525763,M5525764,M5525766,M5525767,M5525769,M6179510,M0024243,M0041746,M0341969,M0341965,M0041688,M0041697,M0041693,M0046168,M0046170,M0046166,M0096879,M0096887,M5480389,M5650805,M0017126,M0017127,M0017128,M0017129,M0017130,M0017131,M0017132,M0017133,M5766711,M0017134,M0017135,M0017136,M0017137,M5207790,M0048236,M0048237,M0048238,M0048239,M0048240,M0068606,M5207830,M0088875,M0088876,M0088877,M0000138,M0061603,M0290204,M0012303,M0012304,M0012305'
